# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhila1619/Excler-/blob/main/Day_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Text to generate WordCloud from
text = 'data science machine learning artificial intelligence'

# Create a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Display the WordCloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Remove the axis
plt.show()

# Save the WordCloud as an image file
wordcloud.to_file('wordcloud_image.png')
print("WordCloud image saved as 'wordcloud_image.png'")
# Out:
# WordCloud image saved as 'wordcloud_image.png'

# %%
pip install wordcloud matplotlib
